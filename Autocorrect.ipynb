# %%
# importing the nltk suite 
import nltk
  
# importing jaccard distance
# and ngrams from nltk.util
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams

# %%
# Downloading and importing
# package 'words' from nltk corpus
nltk.download('words')
from nltk.corpus import words
  
  
correct_words = words.words()
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
import pandas as pd
incorrect_words=pd.read_csv('/content/Missspell.csv')
incorrect_words.head()
# Out:
#      words
# 0   corect
# 1    haapy
# 2     godd
# 3  singere
# 4    schol

# %%
# list of incorrect spellings
# that need to be corrected 
#incorrect_words=['happpy', 'azmaing', 'intelliengt','wronge','corect','speling']
  
# loop for finding correct spellings
# based on jaccard distance
# and printing the correct word
for word in incorrect_words.words:
    temp = [(jaccard_distance(set(ngrams(word, 2)),
                              set(ngrams(w, 2))),w)
            for w in correct_words if w[0]==word[0]]
    print(sorted(temp, key = lambda val:val[0])[0][1])
# Out:
# corector
# happy
# god
# singer
# schola
# college
# humet
# monny
# mani
# formal
# stud
# indan
# wold
# dag
# lagan
# mandant
# chai
# daleth
# projacient
# simper
# randan
# ganam
# forme
# coppy
# foal
# din
# lance
# sang
# amazing
# indignantly
# hiper
# acerbity
# mines
# matra
# jar
# hamble
# request
# acceptable
# accidently
# accommodate
# achieve
# acknowledge
# acquaintance
# acquire
# acquire
# acquit
# changa
# col
# catamited
# conscience
# definitely
# displant
# drunkenness
# dumbbell
# embar
# equipment
# exceed
# existence
# firry
# fore
# gage
# grateful
# harass
# hight
# human
# immediate
# independent
# jewelry
# judgment
# karela
# library
# license
# acrose
# aggressive
# arrantly
# basically
# benign
# business
# calendry
# category
# coming
# comity
# finally
# fourth
# forward
# further
# government
# gramme
# guaraguao
# great
# guard
# happen
# harass
# knowledge
# misspell
# necessary
# occasion
# oniomania
# parallel
# piece
