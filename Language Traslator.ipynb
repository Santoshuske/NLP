# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/dataset')

# %%
import pandas as pd
df=pd.read_csv('English.csv')
df.head()
# Out:
#   English words/sentences
# 0                     Hi.
# 1                    Run!
# 2                    Run!
# 3                    Who?
# 4                    Wow!

# %%
df.shape
# Out:
# (175621, 1)

# %%
df=df.rename(columns={'English words/sentences':'words_sentences'})
df.head()
# Out:
#   words_sentences
# 0             Hi.
# 1            Run!
# 2            Run!
# 3            Who?
# 4            Wow!

# %%
# Replacing punctuations with space
df['words_sentences_processed'] = df['words_sentences'].str.replace("[^a-zA-Z0-9]", " ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
df
# Out:
#                                           words_sentences  \
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                 words_sentences_processed
# 0                                                     Hi
# 1                                                    Run
# 2                                                    Run
# ...

# %%
# make entire text lowercase
df['words_sentences_processed'] = [review.lower() for review in df['words_sentences_processed']]

# %%
df
# Out:
#                                           words_sentences  \
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                 words_sentences_processed
# 0                                                     hi
# 1                                                    run
# 2                                                    run
# ...

# %% [markdown]
# Remove stop words

# %%
df1=df['words_sentences_processed'].head(100)

# %%
# !pip install translate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from translate import Translator
translator= Translator(to_lang="German")
translation = translator.translate("Good Morning!")
print (translation)
# Out:
# Guten Morgen!

# %%
for i in df1:
  #print(i)
  translator= Translator(to_lang="Spanish")
  translation = translator.translate(i)
  print (translation)
# Out:
# hola
# ejecutar
# ejecutar
# sólo respira intencionando que eres un ser ilimitado, que el poder de crear está adentro tuyo.
# me asombra
# ,prenderle fuego
# ayuda
# saltar
# detener
# detener
# detener
# espera
# espera
# continuar
# continuar
# continuar
# hola
# hola
# Ya veo.
# Yo intento
# Gané.
# Gané.
# Gané.
# oh no
# ataque
# ataque
# saludos
# saludos
# saludos
# saludos
# levantarse
# Ir ahora
# Ir ahora
# Ir ahora
# entendido
# entendido
# entendido
# entendido
# entendido
# Sube en el coche.
# Sube en el coche.
# Abrázame
# Abrázame
# Caí
# Caí
# Yo sé
# Salí
# Salí
# Mentí.
# perdiste
# pague
# MM
# MM
# MM
# escuchar
# que va
# que va
# que va
# que va
# que va
# que va
# que va
# que va
# que va
# propiamente
# propiamente
# propiamente
# Gracias
# Lo intentamos
# ganamos
# ganamos
# ganamos
# ganamos
# Pregúntale a Tom.
# impresionanteComment
# Esté calmado
# Esté calmado
# Esté calmado
# – Se fue.
# Sea justo
# Sea justo
# Sea justo
# Sea justo
# Sea justo
# ...

# %%
for i in df1:
  #print(i)
  translator= Translator(to_lang="German")
  translation = translator.translate(i)
  print (translation)
# Out:
# hallo
# Ausführen
# Ausführen
# WHO
# Wow
# Feuer
# Hilfe
# springen
# Stopp
# Stopp
# Stopp
# wait
# wait
# Weiter
# Weiter
# Weiter
# hallo
# hallo
# Ich verstehe
# ich suche auf
# ich werde
# ich werde
# ich werde
# Oh nein
# Angriff
# Angriff
# danke
# danke
# danke
# danke
# get up
# Los
# Los
# Los
# ich habe verstanden
# ich habe verstanden
# ich habe verstanden
# ich habe verstanden
# ich habe verstanden
# Steig ein!
# Steig ein!
# Drück mich!
# Drück mich!
# ich fiel anheim
# ich fiel anheim
# i know
# ich ließ
# ich ließ
# Ich habe gelogen.
# Die Adresse habe ich
# selbst gezahlt
# I M
# I M
# I M
# Listen
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# auf keinen Fall
# wirklich
# wirklich
# wirklich
# danke
# wir bezwecken
# Wir haben gewonnen.
# Wir haben gewonnen.
# Wir haben gewonnen.
# Wir haben gewonnen.
# Frag Tom!
# fantastisch
# «Seid beruhigt.»
# «Seid beruhigt.»
# ...

# %%
for i in df1:
  #print(i)
  translator= Translator(to_lang="French")
  translation = translator.translate(i)
  print (translation)
# Out:
# hi
# Cours
# Cours
# qui
# Waouh
# Feu
# aide
# sauter
# arrêter
# arrêter
# arrêter
# Attendre
# Attendre
# continuer
# continuer
# continuer
# salut
# salut
# Je les ai cherchés.
# J'essaie
# j'ai gagné
# j'ai gagné
# j'ai gagné
# Oh roxy,
# attaque
# attaque
# cheers
# cheers
# cheers
# cheers
# lever
# go
# go
# go
# je l'ai
# je l'ai
# je l'ai
# je l'ai
# je l'ai
# Monte.
# Monte.
# je vous donne un gros calin
# je vous donne un gros calin
# Je suis tombé
# Je suis tombé
# Je sais
# J'ai quitté
# J'ai quitté
# J'ai menti
# J'ai perdu
# Payé
# i m
# i m
# i m
# Écoutez
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# aucun moyen
# vraiment
# vraiment
# vraiment
# thanks
# nous asseyons
# nous avons gagné
# nous avons gagné
# nous avons gagné
# nous avons gagné
# Demande à Tom.
# impressionnante
# Calme.
# Calme.
# Calme.
# Be Cool
# Soyez juste
# Soyez juste
# Soyez juste
# Soyez juste
# Soyez juste
# Soyez juste
# ...
